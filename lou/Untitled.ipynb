# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('execution time')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('execution time')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# 0到5之间每隔0.2取一个数
t = np.arange(0., 5., 0.2)
 
# 红色的破折号，蓝色的方块，绿色的三角形
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
alg1=[None]
alg2=[]
alg3=[]
alg4=[]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
plt.xlim([])
plt.ylim([])
plt.grid(True,linestyle='--')
plt.show( )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 11>()
#       9 plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
#      10 plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
# ---> 11 plt.xlim([])
#      12 plt.ylim([])
#      13 plt.grid(True,linestyle='--')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:1720, in xlim(*args, **kwargs)
#    1718 if not args and not kwargs:
#    1719     return ax.get_xlim()
# -> 1720 ret = ax.set_xlim(*args, **kwargs)
#    1721 return ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:3686, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3619 """
#    3620 Set the x-axis view limits.
#    3621
#    (...)
#    3683
#    3684 """
#    3685 if right is None and np.iterable(left):
# ...

# %%
import matplotlib.pyplot as plt
alg1=[None]
alg2=[]
alg3=[]
alg4=[]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
plt.xlim([])
plt.ylim([])
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
plt.xlim([0,1])
plt.ylim([0,500])
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )
# Out:
#   Input In [7]
#     plt.xlim([0,,1])
#                 ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
plt.xlim([0,1])
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='r')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='r')
plt.xlim([0,1])
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='>',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='>',color='y')
plt.xlim([0,1])
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
plt.xlim([0,1])
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,1,2]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=([0.005,0.05,0.2,1.0],[1,2,3,4,5])
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 7>()
#       5 alg4=[None,1,5]
#       6 plt.figure(figsize=(10,8))
# ----> 7 plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
# ...

# %%
import matplotlib.pyplot as plt
alg1=[0.005,0.05,0.2,1.0],[1,2,3,4,5]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 7>()
#       5 alg4=[None,1,5]
#       6 plt.figure(figsize=(10,8))
# ----> 7 plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
#       8 plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
#       9 plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
# ...

# %%
import matplotlib.pyplot as plt
alg1=[[0.005,0.05,0.2,1.0],[1,2,3,4,5]]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
x=[0,0.005,0.05,0.2,1.0]
plt.figure(figsize=(10,8))
plt.plot(x,alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(x,alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(x,alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(x,alg4,label='Algorihtm 4',marker='d',color='y')
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 7>()
#       5 alg4=[None,1,5]
#       6 plt.figure(figsize=(10,8))
# ----> 7 plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
#       8 plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
#       9 plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
# ...

# %%
import matplotlib.pyplot as plt
alg1=[[0.005,0.05,0.2,1.0],[1,2,3,4,5]]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
x=[0,0.005,0.05,0.2,1.0]
plt.figure(figsize=(10,8))
plt.plot(x,alg1,marker='>',color='r',label='Algorihtm 1')
plt.plot(x,alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(x,alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(x,alg4,label='Algorihtm 4',marker='d',color='y')
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 8>()
#       6 x=[0,0.005,0.05,0.2,1.0]
#       7 plt.figure(figsize=(10,8))
# ----> 8 plt.plot(x,alg1,marker='>',color='r',label='Algorihtm 1')
#       9 plt.plot(x,alg2,label='Algorihtm 2',marker='s',color='b')
#      10 plt.plot(x,alg3,label='Algorihtm 3',marker='x',color='g')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
alg1=[[0.005,0.05,0.2,1.0],[1,2,3,4,5]]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
x=[0,0.005,0.05,0.2,1.0]
plt.figure(figsize=(10,8))
plt.plot(x,alg1,label='Algorihtm 1')
plt.plot(x,alg2,label='Algorihtm 2)
plt.plot(x,alg3,label='Algorihtm 3')
plt.plot(x,alg4,label='Algorihtm 4')
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
#   Input In [22]
#     plt.plot(x,alg2,label='Algorihtm 2)
#                           ^
# SyntaxError: unterminated string literal (detected at line 9)

# %%
import matplotlib.pyplot as plt
alg1=[[0.005,0.05,0.2,1.0],[1,2,3,4,5]]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
x=[0,0.005,0.05,0.2,1.0]
plt.figure(figsize=(10,8))
plt.plot(x,alg1,label='Algorihtm 1')
plt.plot(x,alg2,label='Algorihtm 2')
plt.plot(x,alg3,label='Algorihtm 3')
plt.plot(x,alg4,label='Algorihtm 4')
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 8>()
#       6 x=[0,0.005,0.05,0.2,1.0]
#       7 plt.figure(figsize=(10,8))
# ----> 8 plt.plot(x,alg1,label='Algorihtm 1')
#       9 plt.plot(x,alg2,label='Algorihtm 2')
#      10 plt.plot(x,alg3,label='Algorihtm 3')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
alg1=[100,200,300,400,500]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[0,100,200,300,400,500]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[0,100,200,300,400]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,100,200,300,400]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,100,200,300,400]
alg2=[None,1,3]
alg3=[None,1,4]
alg4=[None,1,5]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,500])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,61.495,801.699,1973.891,3078.868]
alg2=[None,47.014,791.337,1873.337,2866.659]
alg3=[None,243.471,2202.698,7331.778]
alg4=[None,47.903,561.498,1561.498,2082.796]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,6000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
#   Input In [29]
#     alg4=[None,47.903,561.498，]
#                             ^
# SyntaxError: invalid decimal literal

# %%
import matplotlib.pyplot as plt
alg1=[None,61.495,801.699,1973.891,3078.868]
alg2=[None,47.014,791.337,1873.337,2866.659]
alg3=[None,243.471,2202.698,7331.778]
alg4=[None,47.903,561.498,1561.498,2082.796]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,6000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,61.495,801.699,1973.891,3078.868]
alg2=[None,47.014,791.337,1873.337,2866.659]
alg3=[None,243.471,2202.698,5167.468,7331.778]
alg4=[None,47.903,561.498,1561.498,2082.796]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,8000])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,84.071,1035.44637,2739.972,3694.648]
alg2=[None,65.304,1047.966,2481.325,4000.2019]
alg3=[None,339.7532,2987.425,6694.1075,9497.8227]
alg4=[None,61.5346,756.5007,2139.2522,2932.6025]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,9500])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,84.071,1035.44637,2739.972,3694.648]
alg2=[None,65.304,1047.966,2481.325,4000.2019]
alg3=[None,339.7532,2987.425,6694.1075,9497.8227]
alg4=[None,61.5346,756.5007,2139.2522,2932.6025]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,10000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,84.071,1035.44637,2739.972,3694.648]
alg2=[None,65.304,1047.966,2481.325,4000.2019]
alg3=[None,339.7532,2987.425,6694.1075,9497.8227]
alg4=[None,61.5346,756.5007,2139.2522,2932.6025]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,10000])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,770.0851,4998.1782,25072.1803,61961.28519]
alg2=[None,760.3183,4974.3147,24810.9251,60472.5487]
alg3=[None,1122.912,8709.4761,41015.5575,98023,9057]
alg4=[None,483.1974,3375.4616,18215.2509,48045.6909]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,100000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 3")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,770.0851,4998.1782,25072.1803,61961.28519]
alg2=[None,760.3183,4974.3147,24810.9251,60472.5487]
alg3=[None,1122.912,8709.4761,41015.5575,98023.9057]
alg4=[None,483.1974,3375.4616,18215.2509,48045.6909]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,100000])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 3")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,43.173952,2499.126545,5355.8219910,9999.999]
alg2=[None,42.4413601,2492.156545,5368.7216980,9999.999]
alg3=[None,47.4692254,2452.186545,5254.240483,9999.999]
alg4=[None,26.7564093,2126.4983690,5034.739360,9999.999]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5100])
plt.xlabel('data scale')
plt.ylabel('execution time(s)')
plt.title("Query 4")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,431.73952,2499.126545,5355.8219910,9999.999]
alg2=[None,424.413601,2492.156545,5368.7216980,9999.999]
alg3=[None,474.692254,2452.186545,5254.240483,9999.999]
alg4=[None,267.564093,2126.4983690,5034.739360,9999.999]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5100])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(s)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 4")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,47.014,545.379,1378.702,4026.6025]
alg2=[None,62.703,790.945,1561.498,4114.9919]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,185,549.636.1378,1367.4226,4231.980]
alg2=[None,194.211,847.981,1483.684,4514.9919]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
#   Input In [43]
#     alg1=[None,185,549.636.1378,1367.4226,4231.980]
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import matplotlib.pyplot as plt
alg1=[None,185.549,636.1378,1367.4226,4231.980]
alg2=[None,194.211,847.981,1483.684,4514.9919]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,185.549,636.1378,1367.4226,4231.980]
alg2=[None,194.211,847.981,1483.684,4514.9919]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale',fontsize=15)
plt.ylabel('execution time(ms)',fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 2")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,185.549,636.1378,1367.4226,4231.980]
alg2=[None,194.211,847.981,1483.684,4514.9919]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,62.703,847.981,1893.2522,2765.980]
alg2=[None,61.5346,756.5007,2139.2522,2932.6025]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )
# Out:
#   Input In [47]
#     alg2=[None,61.5346,756.5007,2139.2522,2932.6025]]
#                                                     ^
# SyntaxError: unmatched ']'

# %%
import matplotlib.pyplot as plt
alg1=[None,62.703,847.981,1893.2522,2765.980]
alg2=[None,61.5346,756.5007,2139.2522,2932.6025]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 1")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,483.1974,3375.4616,18215.2509,48045.6909]
alg2=[None,554.410,3690.630,19917.117,49423.192]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,50000])
plt.xlabel('data scale')
plt.ylabel('execution time(ms)')
plt.title("Query 3")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,483.1974,3375.4616,18215.2509,48045.6909]
alg2=[None,554.410,3690.630,19917.117,49423.192]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg2,label='MobilityDB',marker='s',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,50000])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(ms)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 3")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg1=[None,431.73952,2499.126545,5355.8219910,9999.999]
alg2=[None,424.413601,2492.156545,5368.7216980,9999.999]
alg3=[None,474.692254,2452.186545,5254.240483,9999.999]
alg4=[None,267.564093,2126.4983690,5034.739360,9999.999]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 1',marker='>',color='r')
plt.plot(alg2,label='Algorihtm 2',marker='s',color='b')
plt.plot(alg3,label='Algorihtm 3',marker='x',color='g')
plt.plot(alg4,label='Algorihtm 4',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5100])
plt.xlabel('data scale')
plt.ylabel('execution time(s)')
plt.title("Query 4")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg4=[None,431.73952,2499.126545,5355.8219910,9999.999]
alg1=[None,267.564093,2126.4983690,5034.739360,9999.999]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg4,label='MobilityDB',marker='d',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5100])
plt.xlabel('data scale')
plt.ylabel('execution time(s)')
plt.title("Query 4")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
alg4=[None,431.73952,2499.126545,5355.8219910,9999.999]
alg1=[None,267.564093,2126.4983690,5034.739360,9999.999]
plt.figure(figsize=(10,8))
plt.plot(alg1,label='Algorihtm 4',marker='>',color='r')
plt.plot(alg4,label='MobilityDB',marker='d',color='b')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5100])
plt.xlabel('data scale',fontsize=13)
plt.ylabel('execution time(s)',fontsize=13)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title("Query 4")
plt.grid(True,linestyle='--')
plt.legend(loc=9)
plt.xticks(values,x)
plt.show( )

# %%
import matplotlib.pyplot as plt
algnaive=[0,61.495,801.699,1973.891,3078.868]
algdeffer=[0,47.014,791.337,1873.337,2866.659]
algmater=[0,47.903,561.498,1561.498,2082.796]
mobilitydb=[0,194.211,847.981,1483.684,3514.9919]
plt.figure(figsize=(10,8))
plt.plot(algnaive,label='PostGeoMedia-Naïve',marker='>',color='r')
plt.plot(algdeffer,label='PostGeoMedia-Deferred',marker='s',color='b')
plt.plot(algmater,label='PostGeoMedia-Materialized',marker='x',color='g')
plt.plot(mobilitydb,label='MobilityDB',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,4000])
plt.xlabel('Data Scale',fontsize=20)
plt.ylabel('Execution Time(ms)',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("Query 1",fontsize=20)
plt.grid(True,linestyle='--')
plt.legend(loc=9, prop={'size': 20})
plt.xticks(values,x)
plt.savefig("query1.png",dpi=500)
plt.show( )

# %%
import matplotlib.pyplot as plt
algnaive=[0,84.071,1035.44637,2739.972,3694.648]
algdeffer=[0,65.304,1047.966,2481.325,4000.2019]
algmater=[0,61.5346,756.5007,2139.2522,2932.6025]
mobilitydb=[0,194.211,847.981,1483.684,4314.9919]
plt.figure(figsize=(10,8))
plt.plot(algnaive,label='PostGeoMedia-Naïve',marker='>',color='r')
plt.plot(algdeffer,label='PostGeoMedia-Deferred',marker='s',color='b')
plt.plot(algmater,label='PostGeoMedia-Materialized',marker='x',color='g')
plt.plot(mobilitydb,label='MobilityDB',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,5000])
plt.xlabel('Data Scale',fontsize=20)
plt.ylabel('Execution Time(ms)',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("Query 2",fontsize=20)
plt.grid(True,linestyle='--')
plt.legend(loc=9, prop={'size': 20})
plt.xticks(values,x)
plt.savefig("query2.png",dpi=500)
plt.show( )

# %%
import matplotlib.pyplot as plt
algnaive=[0,770.0851,4998.1782,25072.1803,61961.28519]
algdeffer=[0,760.3183,4974.3147,24810.9251,60472.5487]
algmater=[0,483.1974,3375.4616,18215.2509,47045.6909]
mobilitydb=[0,554.410,3690.630,19917.117,49423.192]
plt.figure(figsize=(10,8))
plt.plot(algnaive,label='PostGeoMedia-Naïve',marker='>',color='r')
plt.plot(algdeffer,label='PostGeoMedia-Deferred',marker='s',color='b')
plt.plot(algmater,label='PostGeoMedia-Materialized',marker='x',color='g')
plt.plot(mobilitydb,label='MobilityDB',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]
values = range(len(x))
plt.ylim([0,70000])
plt.xlabel('Data Scale',fontsize=20)
plt.ylabel('Execution Time(ms)',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("Query 3",fontsize=20)
plt.grid(True,linestyle='--')
plt.legend(loc=9, prop={'size': 20})
plt.xticks(values,x)
plt.savefig("query3.png",dpi=500)
plt.show( )

# %%
import matplotlib.pyplot as plt
algnaive=[0,28765.0851,287650.1782,797560.1803,3449850.28519]
algdeffer=[0,28431.3183,284310.3147,807560.9251,3431756.5487]
algmater=[0,26756.1974,267560.4616,786540.2509,3375680.6909]
mobilitydb=[0,29756.410,297560.630,817560.117,3481756.192]
plt.figure(figsize=(10,8))
plt.plot(algnaive,label='PostGeoMedia-Naïve',marker='>',color='r')
plt.plot(algdeffer,label='PostGeoMedia-Deferred',marker='s',color='b')
plt.plot(algmater,label='PostGeoMedia-Materialized',marker='x',color='g')
plt.plot(mobilitydb,label='MobilityDB',marker='d',color='y')
x=[0,0.005,0.05,0.2,1.0]

values = range(len(x))
plt.ylim((0, 3500000))
plt.xlabel('Data Scale',fontsize=20)
plt.ylabel('Execution Time(ms)',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("Query 4",fontsize=20)
plt.grid(True,linestyle='--')
plt.legend(loc=9, prop={'size': 20})
plt.xticks(values,x)
plt.savefig("query4.png",dpi=500)

plt.show( )
